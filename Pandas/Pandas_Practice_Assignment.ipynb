# %% [markdown]
# # Pandas Practice Notebook
# Dear Students this notebook will help you practice Important Pandas operations step-by-step.

# %% [markdown]
# ## 1. File Import using Pandas
# Below are some examples to import files in Pandas and practice questions.

# %%
# Example: Importing CSV, Excel, and JSON files
import pandas as pd

# Read CSV
df_csv = pd.read_csv('data.csv')

# Read Excel
df_excel = pd.read_excel('data.xlsx')

# Read JSON
df_json = pd.read_json('data.json')

# %% [markdown]
# ### Practice Questions
# 1. Import the file `sales.csv` and display the first 5 rows.
# 2. Import the Excel file `students.xlsx` and check its columns.
# 3. Import any JSON file and find its shape.

# %%
# Answer here

import pandas as pd

# Read CSV
df_csv = pd.read_csv('Student_CSV.csv')

# Read Excel
df_excel = pd.read_excel('Student_XLSX.xlsx')

# Read JSON
df_json = pd.read_json('Student_JSON.json')

# %%
df_csv.head()
# Out:
#   StudentID       Name       City  Age  Score  JoinedDate  IsActive
# 0      S001  Student_1       Pune   26  58.55  2024-01-01      True
# 1      S002  Student_2    Kolkata   22  76.41  2024-01-02     False
# 2      S003  Student_3    Kolkata   18  92.66  2024-01-03     False
# 3      S004  Student_4  Bengaluru   22  58.34  2024-01-04     False
# 4      S005  Student_5      Delhi   29  81.87  2024-01-05      True

# %%
df_excel.columns
# Out:
# Index(['StudentID', 'Name', 'City', 'Age', 'Score', 'JoinedDate', 'IsActive'], dtype='object')

# %%
df_json.shape
# Out:
# (100, 7)

# %% [markdown]
# ## 2. File Export using Pandas
# You can export data to different formats like CSV, Excel, and JSON.

# %%
# Example: Exporting DataFrame to different formats
#df_csv.to_csv('output.csv', index=False)
#df.to_excel('output.xlsx', index=False)
#df.to_json('output.json')

# %% [markdown]
# ### Practice Questions
# 1. Export any given DataFrame to CSV format without index.
# 2. Export the same DataFrame to Excel with the name 'Sheet1'.
# 3. Export to JSON format with indentation.

# %%
# Answer here
df_csv.to_csv('output.csv', index=False)

# %%
df_csv.to_excel('output.xlsx',sheet_name='Sheet1',index=False)

# %%
df_json.to_json('output.json',indent=4)

# %% [markdown]
# ## 3. Creating Series and DataFrames

# %%
# Example: Creating Series and DataFrame
series = pd.Series([10, 20, 30], name='Sales')
data = {'Name': ['Amit', 'Riya', 'John'], 'Age': [22, 24, 26]}
df = pd.DataFrame(data)
print(series)
print(df)

# %% [markdown]
# ### Practice Questions
# 1. Create a Series of 5 numbers named 'Marks'.
# 2. Create a DataFrame of 3 students with columns 'Name', 'Score', 'City'.
# 3. Print shape, head, and describe of your DataFrame.

# %%
# Answer here
marks = pd.Series([85,92,78,65,90],name='marks')
print(marks)
# Out:
# 0    85
# 1    92
# 2    78
# 3    65
# 4    90
# Name: marks, dtype: int64

# %%
dic =  {
    'Name':['Akash','Ajay','Atul'],
    'Score':[90,80,70],
    'City':['HRI','BLR','DEL']
}

df = pd.DataFrame(dic)

# %%
df.head()
# Out:
#     Name  Score City
# 0  Akash     90  HRI
# 1   Ajay     80  BLR
# 2   Atul     70  DEL

# %%
df.shape
# Out:
# (3, 3)

# %%
df.describe()
# Out:
#        Score
# count    3.0
# mean    80.0
# std     10.0
# min     70.0
# 25%     75.0
# 50%     80.0
# 75%     85.0
# max     90.0

# %% [markdown]
# ## 4. Indexing and Slicing in Pandas

# %%
# Example: Indexing and Slicing
df['Name']
df[['Name', 'Age']]
df.iloc[0:2]
df.loc[df['Age'] > 22]

# %% [markdown]
# ### Practice Questions
# 1. Select only the 'Score' column from your DataFrame.
# 2. Retrieve rows from index 1 to 3.
# 3. Filter rows where 'Age' > 23.

# %%
# Answer here
df['Score']
# Out:
# 0    90
# 1    80
# 2    70
# Name: Score, dtype: int64

# %%
df.iloc[1:4]
# Out:
#    Name  Score City
# 1  Ajay     80  BLR
# 2  Atul     70  DEL

# %%
df_csv[df_csv['Age']>23]
# Out:
#    StudentID        Name       City  Age  Score  JoinedDate  IsActive
# 0       S001   Student_1       Pune   26  58.55  2024-01-01      True
# 4       S005   Student_5      Delhi   29  81.87  2024-01-05      True
# 5       S006   Student_6    Chennai   28  71.80  2024-01-06      True
# 7       S008   Student_8       Pune   27  79.73  2024-01-08      True
# 11      S012  Student_12    Chennai   24  59.16  2024-01-12      True
# 12      S013  Student_13       Pune   29  54.83  2024-01-13      True
# 14      S015  Student_15       Pune   25  44.18  2024-01-15      True
# 15      S016  Student_16    Chennai   29  87.01  2024-01-16      True
# 16      S017  Student_17  Bengaluru   30  78.77  2024-01-17      True
# 19      S020  Student_20       Pune   30  52.89  2024-01-20      True
# 21      S022  Student_22  Bengaluru   30  79.10  2024-01-22      True
# 22      S023  Student_23    Chennai   29  57.25  2024-01-23     False
# 23      S024  Student_24    Kolkata   26  54.63  2024-01-24      True
# 24      S025  Student_25    Chennai   25  92.80  2024-01-25     False
# 29      S030  Student_30    Kolkata   24  95.01  2024-01-30      True
# 31      S032  Student_32  Bengaluru   28  85.30  2024-02-01     False
# 32      S033  Student_33    Chennai   25  62.46  2024-02-02     False
# 33      S034  Student_34     Mumbai   28  43.48  2024-02-03      True
# 35      S036  Student_36     Mumbai   25  61.18  2024-02-05      True
# 36      S037  Student_37  Bengaluru   27  40.92  2024-02-06      True
# 37      S038  Student_38     Mumbai   27  54.77  2024-02-07      True
# 38      S039  Student_39      Delhi   25  51.88  2024-02-08     False
# 41      S042  Student_42  Bengaluru   24  70.94  2024-02-11      True
# 43      S044  Student_44    Chennai   25  49.17  2024-02-13      True
# 44      S045  Student_45      Delhi   24  82.99  2024-02-14     False
# 45      S046  Student_46    Chennai   28  48.15  2024-02-15      True
# 47      S048  Student_48       Pune   28  57.38  2024-02-17     False
# 48      S049  Student_49       Pune   27  47.24  2024-02-18     False
# 50      S051  Student_51     Mumbai   24  76.78  2024-02-20      True
# 51      S052  Student_52      Delhi   24  51.53  2024-02-21     False
# 53      S054  Student_54    Kolkata   27  91.29  2024-02-23      True
# 54      S055  Student_55    Kolkata   29  58.68  2024-02-24     False
# 55      S056  Student_56       Pune   28  45.46  2024-02-25     False
# 56      S057  Student_57    Chennai   27  85.66  2024-02-26     False
# 57      S058  Student_58  Hyderabad   27  82.65  2024-02-27      True
# 58      S059  Student_59     Mumbai   29  84.29  2024-02-28     False
# 59      S060  Student_60    Chennai   27  79.12  2024-02-29      True
# 60      S061  Student_61  Bengaluru   27  44.08  2024-03-01      True
# 64      S065  Student_65    Kolkata   24  72.71  2024-03-05      True
# 65      S066  Student_66  Bengaluru   24  99.93  2024-03-06     False
# 66      S067  Student_67    Chennai   29  89.04  2024-03-07      True
# 68      S069  Student_69  Hyderabad   28  78.73  2024-03-09      True
# 70      S071  Student_71     Mumbai   25  70.38  2024-03-11     False
# 71      S072  Student_72    Kolkata   26  84.85  2024-03-12      True
# 72      S073  Student_73    Kolkata   29  55.53  2024-03-13      True
# 75      S076  Student_76       Pune   26  44.72  2024-03-16      True
# 76      S077  Student_77  Hyderabad   27  44.61  2024-03-17      True
# 77      S078  Student_78    Kolkata   26  62.85  2024-03-18     False
# 79      S080  Student_80       Pune   30  45.54  2024-03-20      True
# 81      S082  Student_82  Bengaluru   26  48.75  2024-03-22      True
# 84      S085  Student_85    Chennai   25  54.01  2024-03-25      True
# 86      S087  Student_87    Kolkata   30  83.96  2024-03-27     False
# 87      S088  Student_88     Mumbai   24  71.16  2024-03-28      True
# 88      S089  Student_89       Pune   28  83.38  2024-03-29     False
# 90      S091  Student_91  Bengaluru   28  97.14  2024-03-31      True
# 91      S092  Student_92    Kolkata   29  60.62  2024-04-01      True
# 92      S093  Student_93    Chennai   29  70.22  2024-04-02     False
# 94      S095  Student_95    Chennai   30  88.45  2024-04-04      True
# 96      S097  Student_97  Bengaluru   26  72.55  2024-04-06     False
# 98      S099  Student_99     Mumbai   29  67.41  2024-04-08      True

# %% [markdown]
# ## 5. Merging and Concatenation

# %%
# Example: Merge and Concat
df1 = pd.DataFrame({'ID': [1,2], 'Name': ['A', 'B']})
df2 = pd.DataFrame({'ID': [1,2], 'Score': [85, 90]})
merged = pd.merge(df1, df2, on='ID')
print(merged)

# Concat
df3 = pd.concat([df1, df2], axis=0, ignore_index=True)

# %% [markdown]
# ### Practice Questions
# 1. Merge two DataFrames 'students' and 'marks' on 'ID'.
# 2. Perform left join between two given DataFrames.
# 3. Concatenate two DataFrames vertically and reset the index.

# %%
# Answer here
students_data = {'ID': [1, 2, 3, 4], 'Name': ['Alice', 'Bob', 'Charlie', 'David']}
students = pd.DataFrame(students_data)

marks_data = {'ID': [1, 2, 5], 'Math': [90, 85, 92], 'Science': [78, 88, 95]}
marks = pd.DataFrame(marks_data)

# %%
merged_df = pd.merge(students, marks, on='ID')
merged_df
# Out:
#    ID   Name  Math  Science
# 0   1  Alice    90       78
# 1   2    Bob    85       88

# %%
lef_joint_df = pd.merge(students,marks, on='ID',how='left')
lef_joint_df
# Out:
#    ID     Name  Math  Science
# 0   1    Alice  90.0     78.0
# 1   2      Bob  85.0     88.0
# 2   3  Charlie   NaN      NaN
# 3   4    David   NaN      NaN

# %%
pd.concat([students,marks],axis=0).reset_index(drop=True)
# Out:
#    ID     Name  Math  Science
# 0   1    Alice   NaN      NaN
# 1   2      Bob   NaN      NaN
# 2   3  Charlie   NaN      NaN
# 3   4    David   NaN      NaN
# 4   1      NaN  90.0     78.0
# 5   2      NaN  85.0     88.0
# 6   5      NaN  92.0     95.0

# %% [markdown]
# ## 6. Pivot Tables and GroupBy

# %%
# Example: Pivot and GroupBy
df = pd.DataFrame({'Region': ['North', 'South', 'North'], 'Month': ['Jan', 'Jan', 'Feb'], 'Sales': [250, 300, 400]})

pivot = df.pivot_table(values='Sales', index='Region', columns='Month', aggfunc='sum', fill_value=0)
grouped = df.groupby('Region')['Sales'].sum()
print(pivot)
print(grouped)
# Out:
# Month   Feb  Jan
# Region
# North   400  250
# South     0  300
# Region
# North    650
# South    300
# Name: Sales, dtype: int64

# %% [markdown]
# ### Practice Questions
# 1. Group the DataFrame by 'Month' and find total sales.
# 2. Create a pivot table to show Region-wise total sales.
# 3. Group data by 'Region' and count number of entries.

# %%
# Answer here
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# Feb    400
# Jan    550
# Name: Sales, dtype: int64

# %%
region_sales_pivot = pd.pivot_table(df, values='Sales', index='Region', aggfunc='sum')
region_sales_pivot
# Out:
#         Sales
# Region
# North     650
# South     300

# %%
df.groupby('Region').size()
# Out:
# Region
# North    2
# South    1
# dtype: int64

# %% [markdown]
# ## Optional Practice (Medium Level)
# These questions test your overall understanding of Pandas.

# %% [markdown]
# 1. Import a dataset and clean all missing values, rename columns properly, and export it back to Excel.
#
# Dataset- https://drive.google.com/file/d/1kw_Sdib3WCo_acQYA851poCUdKcWgfYs/view?usp=sharing

# %%
# Answer here

df = pd.read_csv('messy_data.csv')
df.head()
# Out:
#      Name   Age(Years)    City  Sales( Rs)
# 0     Amit        25.0   Delhi      2500.0
# 1   Priya          NaN  Mumbai      3000.0
# 2      NaN        30.0   Delhi         NaN
# 3    Rohan        22.0     NaN      2000.0
# 4     Neha        28.0    Pune      4000.0

# %%
df['Age(Years)']=df['Age(Years)'].fillna(0)
df['City']= df[' City'].fillna('Missing')
df['Sales( Rs)'] = df['Sales( Rs)'].fillna(0)

# %%
df.head()

df.columns
df['Name '] = df['Name '].fillna('Akash')

# %%
df.rename(columns={'Age(Years)':'Age', 'Sales( Rs)': 'Sales','Name ':'Name'},inplace=True)

# %%
df
# Out:
#       Name   Age    City   Sales     City
# 0     Amit  25.0   Delhi  2500.0    Delhi
# 1   Priya    0.0  Mumbai  3000.0   Mumbai
# 2    Akash  30.0   Delhi     0.0    Delhi
# 3    Rohan  22.0     NaN  2000.0  Missing
# 4     Neha  28.0    Pune  4000.0     Pune
# 5    Akash  30.0   Delhi     0.0    Delhi

# %%
with pd.ExcelWriter('cleaned_messy_data.xlsx') as writer:
  df.to_excel(writer, sheet_name='Students_Data',index=False)

# %% [markdown]
# 2. Combine multiple CSV files from a folder into one DataFrame and find top 5 entries by a numeric column like 'Sales'.
#
# Dataset- https://drive.google.com/drive/folders/1zgJs_6r8Aa_-93YXmYXfxOK5L4hVUI9Q?usp=sharing

# %%
# Answer here
df_jan = pd.read_csv('sales_jan.csv')
df_jan
# Out:
#    ID Product  Sales Month
# 0   1       A   1200   Jan
# 1   2       B   1500   Jan
# 2   3       C   1100   Jan
# 3   4       D    900   Jan
# 4   5       E   1700   Jan

# %%
df_feb = pd.read_csv('sales_feb.csv')
df_feb
# Out:
#    ID Product  Sales Month
# 0   6       A   1300   Feb
# 1   7       B   1600   Feb
# 2   8       C   1000   Feb
# 3   9       D    950   Feb
# 4  10       E   1750   Feb

# %%
df_mar = pd.read_csv('sales_mar.csv')
df_mar
# Out:
#    ID Product  Sales Month
# 0  11       A   1250   Mar
# 1  12       B   1400   Mar
# 2  13       C   1150   Mar
# 3  14       D    980   Mar
# 4  15       E   1650   Mar

# %%
merged_df = pd.merge(df_jan,df_feb, on='Product',how='inner')
merged_df
# Out:
#    ID_x Product  Sales_x Month_x  ID_y  Sales_y Month_y
# 0     1       A     1200     Jan     6     1300     Feb
# 1     2       B     1500     Jan     7     1600     Feb
# 2     3       C     1100     Jan     8     1000     Feb
# 3     4       D      900     Jan     9      950     Feb
# 4     5       E     1700     Jan    10     1750     Feb

# %%
merged_df_mar = pd.merge(merged_df, df_mar, on='Product', how='inner')
merged_df_mar
# Out:
#    ID_x Product  Sales_x Month_x  ID_y  Sales_y Month_y  ID  Sales Month
# 0     1       A     1200     Jan     6     1300     Feb  11   1250   Mar
# 1     2       B     1500     Jan     7     1600     Feb  12   1400   Mar
# 2     3       C     1100     Jan     8     1000     Feb  13   1150   Mar
# 3     4       D      900     Jan     9      950     Feb  14    980   Mar
# 4     5       E     1700     Jan    10     1750     Feb  15   1650   Mar

# %%
merged_df_mar['Sales'].sort_values(ascending=False)
# Out:
# 4    1650
# 1    1400
# 0    1250
# 2    1150
# 3     980
# Name: Sales, dtype: int64
